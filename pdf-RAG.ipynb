# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/pdf-RAG')
# !ls
# Out:
# app.py	       pdf-RAG.ipynb  readme-7.md      requirements_simplified.txt
# config.py      __pycache__    readme-8.2.1.md  requirements.txt
# data	       rag	      readme-8.2.2.md  services
# documentation  readme-4.md    readme-8.2.3.md  ui
# loaders        readme-5.md    readme-8.2.4.md
# main.py        readme-6.md    README.md

# %%
# !pip install -r requirements.txt -q

# %%
import requests
from google.colab import userdata

api_key = userdata.get("GEMINI_KEY")
url = f"https://generativelanguage.googleapis.com/v1beta/models?key={api_key}"

response = requests.get(url)
models = response.json()

for model in models["models"]:
    print(model["name"])
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# ...

# %%
# !pip install pyngrok -q

# %%
# !python documentation/chunk_experiment.py > documentation/chunk_experiment_results.csv

# Xem nhanh kết quả
import pandas as pd
df = pd.read_csv("documentation/chunk_experiment_results.csv")
display(df.head(20))
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/pdf-RAG/documentation/chunk_experiment.py", line 8, in <module>
#     from langchain_community.vectorstores import FAISS
#   File "<frozen importlib._bootstrap>", line 1412, in _handle_fromlist
#   File "/usr/local/lib/python3.12/dist-packages/langchain_community/vectorstores/__init__.py", line 529, in __getattr__
#     module = importlib.import_module(_module_lookup[name])
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/langchain_community/vectorstores/faiss.py", line 24, in <module>
#     from langchain_core.documents import Document
#   File "<frozen importlib._bootstrap>", line 1412, in _handle_fromlist
# ...

# %%
from google.colab import userdata
import os

# Set key vào environment variable trước
os.environ["GEMINI_KEY"] = userdata.get("GEMINI_KEY")

# Rồi mới chạy Streamlit
from pyngrok import ngrok
ngrok.kill()
ngrok.set_auth_token(userdata.get("NGROK_KEY"))
public_url = ngrok.connect(8501)
print(f"✅ Mở app tại: {public_url}")
# !streamlit run main.py --server.port 8501 &
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2200/1000922768.py in <cell line: 0>()
#       3
#       4 # Set key vào environment variable trước
# ----> 5 os.environ["GEMINI_KEY"] = userdata.get("GEMINI_KEY")
#       6
#       7 # Rồi mới chạy Streamlit
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      60   # thread-safe.
#      61   with _userdata_lock:
# ---> 62     resp = _message.blocking_request(
#      63         'GetSecret', request={'key': key}, timeout_sec=10
#      64     )
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# ...
